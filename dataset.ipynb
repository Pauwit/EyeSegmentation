# %% [markdown]
# # Create Dataset and helper functions

# %%
import cv2
import os
import shutil
from pathlib import Path
import matplotlib.pyplot as plt
import math
import shutil
import numpy as np

# %%
def save_frame(path, frame):
    """
    Saves grayscale tensor to PNG image
    :param path: The path (with .png)
    :param frame: Frame to save
    :return: boolean: success
    """
    if not path.endswith('.png'):
        print('Path does not end with .png')
        return False
    return cv2.imwrite(path, frame, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])

# %%
def extract_frames(video_path, output_folder, interval_sec=0.5):
    """
    Extracts frames from video
    :param video_path: The video path
    :param output_folder: The output folder where every frame will be saved
    :param interval_sec: The interval between frames
    :return: boolean: success
    """
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Error: Cannot open video.")
        return False

    _, video_name = os.path.split(video_path)
    video_name_without_ext, _ = os.path.splitext(video_name)

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = total_frames / fps
    print(f"FPS: {fps}, Total Frames: {total_frames}, Duration: {duration:.2f} sec")

    frame_interval = int(fps * interval_sec)
    frame_idx = 0
    saved_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_idx % frame_interval == 0:
            filename = os.path.join(output_folder, video_name_without_ext + f"_{saved_count:04d}.png")
            save_frame(filename, frame)
            saved_count += 1

        frame_idx += 1

    cap.release()
    print(f"Extracted {saved_count} frames.")
    return True

# %%
extract_frames(os.path.join("test", "250905_GHW_1_HD_1_M0.avi"), output_folder=os.path.join("test", "250905_GHW_1_HD_1_M0"), interval_sec=0.2)
# Out:
# FPS: 30.0, Total Frames: 255, Duration: 8.50 sec
# Extracted 43 frames.
# True

# %%
def duplicate_file(src, dest):
    return shutil.copyfile(src, dest)

# %%
for i in range(1, 43):
    duplicate_file("data/eye/train_masks/250905_GHW_1_HD_1_M0_0000_mask.png", f"data/eye/train_masks/250905_GHW_1_HD_1_M0_{i:04d}_mask.png")

# %%
def rename_files_sequentially(directory: str, extension: str = ".png"):
    """
    Renames all files in a directory to sequential names like 0001.png, 0002.png, ...

    Args:
        directory (str): Path to the directory containing files.
        extension (str): Desired extension for renamed files (default: ".png").
    """
    dir_path = Path(directory).resolve()

    files = sorted([f for f in dir_path.iterdir() if f.is_file()])

    for i, file in enumerate(files, start=1):
        new_name = f"{i:04d}{extension}"
        new_path = dir_path / new_name
        file.rename(new_path)

    print(f"Renamed {len(files)} files in {dir_path}")

# %%
rename_files_sequentially("./data/eye/train")
# Out:
# Renamed 804 files in C:\Users\Domodekavkaz\Documents\Stage\papillae_detection\data\eye\train

# %% [markdown]
# ---

# %%
def read_paths(file_path: str):
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            path = line.strip()
            if path:  # skip empty lines
                yield str(Path(path).resolve())

# %%
i = 0
for p in read_paths("pngs.txt"):
    duplicate_file(p, f"data/eye/train/{i:04d}.png")
    i += 1

# %%
mask_path = "datasets/segmentation/val/images"
image_path = "data/eye/train"
put_to = "datasets/segmentation/val/tmp"

for filename in os.listdir(mask_path):
    src = os.path.join(image_path, filename)
    dst = os.path.join(put_to, filename)
    shutil.copy(src, dst)
    print(f"Copied {filename} to {dst}")
# Out:
# Copied 0328.png to datasets/segmentation/val/tmp\0328.png
# Copied 0329.png to datasets/segmentation/val/tmp\0329.png
# Copied 0330.png to datasets/segmentation/val/tmp\0330.png
# Copied 0331.png to datasets/segmentation/val/tmp\0331.png
# Copied 0332.png to datasets/segmentation/val/tmp\0332.png
# Copied 0333.png to datasets/segmentation/val/tmp\0333.png
# Copied 0334.png to datasets/segmentation/val/tmp\0334.png
# Copied 0335.png to datasets/segmentation/val/tmp\0335.png
# Copied 0336.png to datasets/segmentation/val/tmp\0336.png
# Copied 0337.png to datasets/segmentation/val/tmp\0337.png
# Copied 0338.png to datasets/segmentation/val/tmp\0338.png
# Copied 0339.png to datasets/segmentation/val/tmp\0339.png
# Copied 0340.png to datasets/segmentation/val/tmp\0340.png
# Copied 0341.png to datasets/segmentation/val/tmp\0341.png
# Copied 0342.png to datasets/segmentation/val/tmp\0342.png
# Copied 0343.png to datasets/segmentation/val/tmp\0343.png
# Copied 0344.png to datasets/segmentation/val/tmp\0344.png
# Copied 0345.png to datasets/segmentation/val/tmp\0345.png
# Copied 0346.png to datasets/segmentation/val/tmp\0346.png
# Copied 0347.png to datasets/segmentation/val/tmp\0347.png
# Copied 0348.png to datasets/segmentation/val/tmp\0348.png
# Copied 0349.png to datasets/segmentation/val/tmp\0349.png
# Copied 0350.png to datasets/segmentation/val/tmp\0350.png
# Copied 0351.png to datasets/segmentation/val/tmp\0351.png
# Copied 0352.png to datasets/segmentation/val/tmp\0352.png
# Copied 0353.png to datasets/segmentation/val/tmp\0353.png
# Copied 0354.png to datasets/segmentation/val/tmp\0354.png
# Copied 0355.png to datasets/segmentation/val/tmp\0355.png
# Copied 0356.png to datasets/segmentation/val/tmp\0356.png
# Copied 0357.png to datasets/segmentation/val/tmp\0357.png
# Copied 0358.png to datasets/segmentation/val/tmp\0358.png
# Copied 0359.png to datasets/segmentation/val/tmp\0359.png
# Copied 0360.png to datasets/segmentation/val/tmp\0360.png
# Copied 0361.png to datasets/segmentation/val/tmp\0361.png
# Copied 0362.png to datasets/segmentation/val/tmp\0362.png
# Copied 0363.png to datasets/segmentation/val/tmp\0363.png
# Copied 0364.png to datasets/segmentation/val/tmp\0364.png
# Copied 0365.png to datasets/segmentation/val/tmp\0365.png
# Copied 0366.png to datasets/segmentation/val/tmp\0366.png
# Copied 0367.png to datasets/segmentation/val/tmp\0367.png
# Copied 0368.png to datasets/segmentation/val/tmp\0368.png
# Copied 0369.png to datasets/segmentation/val/tmp\0369.png
# Copied 0370.png to datasets/segmentation/val/tmp\0370.png
# Copied 0371.png to datasets/segmentation/val/tmp\0371.png
# Copied 0372.png to datasets/segmentation/val/tmp\0372.png
# Copied 0373.png to datasets/segmentation/val/tmp\0373.png
# Copied 0374.png to datasets/segmentation/val/tmp\0374.png
# Copied 0375.png to datasets/segmentation/val/tmp\0375.png
# Copied 0376.png to datasets/segmentation/val/tmp\0376.png
# Copied 0377.png to datasets/segmentation/val/tmp\0377.png
# Copied 0378.png to datasets/segmentation/val/tmp\0378.png
# Copied 0379.png to datasets/segmentation/val/tmp\0379.png
# Copied 0380.png to datasets/segmentation/val/tmp\0380.png
# Copied 0381.png to datasets/segmentation/val/tmp\0381.png
# Copied 0382.png to datasets/segmentation/val/tmp\0382.png
# Copied 0383.png to datasets/segmentation/val/tmp\0383.png
# Copied 0384.png to datasets/segmentation/val/tmp\0384.png
# Copied 0385.png to datasets/segmentation/val/tmp\0385.png
# Copied 0386.png to datasets/segmentation/val/tmp\0386.png
# Copied 0387.png to datasets/segmentation/val/tmp\0387.png
# Copied 0388.png to datasets/segmentation/val/tmp\0388.png
# Copied 0389.png to datasets/segmentation/val/tmp\0389.png
# Copied 0390.png to datasets/segmentation/val/tmp\0390.png
# Copied 0391.png to datasets/segmentation/val/tmp\0391.png
# Copied 0392.png to datasets/segmentation/val/tmp\0392.png
# Copied 0393.png to datasets/segmentation/val/tmp\0393.png
# Copied 0394.png to datasets/segmentation/val/tmp\0394.png
# Copied 0395.png to datasets/segmentation/val/tmp\0395.png
# Copied 0396.png to datasets/segmentation/val/tmp\0396.png
# Copied 0397.png to datasets/segmentation/val/tmp\0397.png
# Copied 0398.png to datasets/segmentation/val/tmp\0398.png
# Copied 0399.png to datasets/segmentation/val/tmp\0399.png
# Copied 0400.png to datasets/segmentation/val/tmp\0400.png
# Copied 0401.png to datasets/segmentation/val/tmp\0401.png
# Copied 0402.png to datasets/segmentation/val/tmp\0402.png
# Copied 0403.png to datasets/segmentation/val/tmp\0403.png
# Copied 0404.png to datasets/segmentation/val/tmp\0404.png
# Copied 0405.png to datasets/segmentation/val/tmp\0405.png
# Copied 0406.png to datasets/segmentation/val/tmp\0406.png
# Copied 0407.png to datasets/segmentation/val/tmp\0407.png

# %%
folder = "datasets/classification/val/left"
ext = ".png"

for filename in os.listdir(folder):
    new_name = filename[:4] + ext
    old_path = os.path.join(folder, filename)
    new_path = os.path.join(folder, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed {new_name} from {old_path} to {new_path}")
# Out:
# Renamed 0042.png from datasets/classification/val/left\0042_png.rf.915be2c3ca71b96fb62fec1537df82a6.jpg to datasets/classification/val/left\0042.png
# Renamed 0046.png from datasets/classification/val/left\0046_png.rf.ca7b53056af71aad53c60cef96404aa0.jpg to datasets/classification/val/left\0046.png
# Renamed 0051.png from datasets/classification/val/left\0051_png.rf.f946821c8f9b5bfc573479dab04d1e54.jpg to datasets/classification/val/left\0051.png
# Renamed 0065.png from datasets/classification/val/left\0065_png.rf.4134fe84e272f93bb78a3693f24243b9.jpg to datasets/classification/val/left\0065.png
# Renamed 0078.png from datasets/classification/val/left\0078_png.rf.760d11e048051a2c2f4c38fedaa1e94b.jpg to datasets/classification/val/left\0078.png
# Renamed 0084.png from datasets/classification/val/left\0084_png.rf.9e7375120761e632586eb17660d8eb66.jpg to datasets/classification/val/left\0084.png
# Renamed 0091.png from datasets/classification/val/left\0091_png.rf.86bae0999c5766f7cbd69896e13d498d.jpg to datasets/classification/val/left\0091.png
# Renamed 0097.png from datasets/classification/val/left\0097_png.rf.7652d3b644678f5a282fefce141784cf.jpg to datasets/classification/val/left\0097.png
# Renamed 0110.png from datasets/classification/val/left\0110_png.rf.f14f93fee2d46e828422724955c79f71.jpg to datasets/classification/val/left\0110.png
# Renamed 0111.png from datasets/classification/val/left\0111_png.rf.ac477ba3609d547209031e53b749008b.jpg to datasets/classification/val/left\0111.png
# Renamed 0117.png from datasets/classification/val/left\0117_png.rf.f43061777b42fc87e1bd383ca2a68be1.jpg to datasets/classification/val/left\0117.png
# Renamed 0125.png from datasets/classification/val/left\0125_png.rf.181eb081338e721b4f9ca32ae4b17331.jpg to datasets/classification/val/left\0125.png
# Renamed 0131.png from datasets/classification/val/left\0131_png.rf.c9c3901adf2f627009acacfd4aa435a8.jpg to datasets/classification/val/left\0131.png
# Renamed 0132.png from datasets/classification/val/left\0132_png.rf.18701ac38bb3216696ae7f0bcc8c57e9.jpg to datasets/classification/val/left\0132.png
# Renamed 0145.png from datasets/classification/val/left\0145_png.rf.1dd7c7072b310e34a795a1d8b9400ebc.jpg to datasets/classification/val/left\0145.png
# Renamed 0151.png from datasets/classification/val/left\0151_png.rf.5d1f0820bc10366bcb0d150ffce8f2bb.jpg to datasets/classification/val/left\0151.png
# Renamed 0158.png from datasets/classification/val/left\0158_png.rf.e21e0cc4259f1ae2454c3cccf2830d80.jpg to datasets/classification/val/left\0158.png
# Renamed 0159.png from datasets/classification/val/left\0159_png.rf.53cf5c6fbaaa184cf452943ae5ee1af1.jpg to datasets/classification/val/left\0159.png
# Renamed 0163.png from datasets/classification/val/left\0163_png.rf.691044cc85e0d0db76891c1777185a7d.jpg to datasets/classification/val/left\0163.png
# Renamed 0181.png from datasets/classification/val/left\0181_png.rf.e264ad2a26f82b9a4becf76222913b15.jpg to datasets/classification/val/left\0181.png
# Renamed 0206.png from datasets/classification/val/left\0206_png.rf.2eb1a2dd1c31307ce2f9a8e085315281.jpg to datasets/classification/val/left\0206.png
# Renamed 0219.png from datasets/classification/val/left\0219_png.rf.feda6160ffb8daf3cadb83d42e28542e.jpg to datasets/classification/val/left\0219.png
# Renamed 0222.png from datasets/classification/val/left\0222_png.rf.a165953db0a24fae3714275b081033db.jpg to datasets/classification/val/left\0222.png
# Renamed 0235.png from datasets/classification/val/left\0235_png.rf.3f41db53947900eb5b48e6f67934731b.jpg to datasets/classification/val/left\0235.png
# Renamed 0243.png from datasets/classification/val/left\0243_png.rf.9517110efedde07306d144d449e6baa1.jpg to datasets/classification/val/left\0243.png
# Renamed 0247.png from datasets/classification/val/left\0247_png.rf.cab97418ae942fad0a27dcd4c5101768.jpg to datasets/classification/val/left\0247.png
# Renamed 0249.png from datasets/classification/val/left\0249_png.rf.8f2984f4b61ade16f19b4656b8e98194.jpg to datasets/classification/val/left\0249.png
# Renamed 0253.png from datasets/classification/val/left\0253_png.rf.ee7a57e7e1ff512923bea3f7aed1ef03.jpg to datasets/classification/val/left\0253.png
# Renamed 0254.png from datasets/classification/val/left\0254_png.rf.e648181cc8f30ec10c95bddbefa3bded.jpg to datasets/classification/val/left\0254.png
# Renamed 0271.png from datasets/classification/val/left\0271_png.rf.8d5023fc729ac64b141383383c9fff08.jpg to datasets/classification/val/left\0271.png
# Renamed 0272.png from datasets/classification/val/left\0272_png.rf.c964f76603d0f34a3c3145903f3e71fa.jpg to datasets/classification/val/left\0272.png
# Renamed 0277.png from datasets/classification/val/left\0277_png.rf.a657107b01c3ec92620b8011a46e2de4.jpg to datasets/classification/val/left\0277.png
# Renamed 0279.png from datasets/classification/val/left\0279_png.rf.3f47ae5c16a20db676cd674cc7166c40.jpg to datasets/classification/val/left\0279.png
# Renamed 0290.png from datasets/classification/val/left\0290_png.rf.4ae69b8404826302d25ff22325a578ca.jpg to datasets/classification/val/left\0290.png
# Renamed 0291.png from datasets/classification/val/left\0291_png.rf.c3ad20f426d7be34a3113161b2180b1e.jpg to datasets/classification/val/left\0291.png
# Renamed 0296.png from datasets/classification/val/left\0296_png.rf.b848e8d188b5927c6b6a3d9d2a90df85.jpg to datasets/classification/val/left\0296.png
# Renamed 0309.png from datasets/classification/val/left\0309_png.rf.5eb46a18d1a7efcab3dbadb1ef811011.jpg to datasets/classification/val/left\0309.png
# Renamed 0325.png from datasets/classification/val/left\0325_png.rf.bdabec3a0c69f309d5a7553a996917a5.jpg to datasets/classification/val/left\0325.png
# Renamed 0326.png from datasets/classification/val/left\0326_png.rf.d6fb961576f77094436d7b4a33168d6e.jpg to datasets/classification/val/left\0326.png
# Renamed 0327.png from datasets/classification/val/left\0327_png.rf.b5827caa6d8679385012d354cb6f4a92.jpg to datasets/classification/val/left\0327.png
# Renamed 0331.png from datasets/classification/val/left\0331_png.rf.dd87545f976752b9e00bc702f552c8a9.jpg to datasets/classification/val/left\0331.png
# Renamed 0336.png from datasets/classification/val/left\0336_png.rf.0338e8429b92bb9352eddab30663a23a.jpg to datasets/classification/val/left\0336.png
# Renamed 0341.png from datasets/classification/val/left\0341_png.rf.435cc2493c1070fa0973ca4097d2693f.jpg to datasets/classification/val/left\0341.png
# Renamed 0343.png from datasets/classification/val/left\0343_png.rf.e99a8d7a6b7caf13dd910b24c2ed3849.jpg to datasets/classification/val/left\0343.png
# Renamed 0347.png from datasets/classification/val/left\0347_png.rf.ce6ddebf9db480c7b0d846e26143bed0.jpg to datasets/classification/val/left\0347.png
# Renamed 0381.png from datasets/classification/val/left\0381_png.rf.6781506afa915df4a093196d36469aab.jpg to datasets/classification/val/left\0381.png
# Renamed 0387.png from datasets/classification/val/left\0387_png.rf.3157e7b83cfcd95d969cd86afae0325c.jpg to datasets/classification/val/left\0387.png
# Renamed 0409.png from datasets/classification/val/left\0409_png.rf.6637ebbe132efaffd55ef9caf33bac61.jpg to datasets/classification/val/left\0409.png
# Renamed 0410.png from datasets/classification/val/left\0410_png.rf.e91cd93a2d9f231e04bfc701fd3aba99.jpg to datasets/classification/val/left\0410.png
# Renamed 0416.png from datasets/classification/val/left\0416_png.rf.5beeb6d33e50769aa5c2c210d10b60cf.jpg to datasets/classification/val/left\0416.png
# Renamed 0437.png from datasets/classification/val/left\0437_png.rf.09a5c1e1aa287a32991225b519272e10.jpg to datasets/classification/val/left\0437.png
# Renamed 0442.png from datasets/classification/val/left\0442_png.rf.92f40180d5c9fb69cb3904f853259de2.jpg to datasets/classification/val/left\0442.png
# Renamed 0446.png from datasets/classification/val/left\0446_png.rf.2605205c113e6fceedf3def1e9a9a52d.jpg to datasets/classification/val/left\0446.png
# Renamed 0449.png from datasets/classification/val/left\0449_png.rf.66c4a2bcc2ee95d12a3743234e73ee07.jpg to datasets/classification/val/left\0449.png
# Renamed 0455.png from datasets/classification/val/left\0455_png.rf.d0746f5b2b4c4a144c41cdb762663cad.jpg to datasets/classification/val/left\0455.png
# Renamed 0456.png from datasets/classification/val/left\0456_png.rf.28494c91a142edeff56714bb951596df.jpg to datasets/classification/val/left\0456.png
# Renamed 0470.png from datasets/classification/val/left\0470_png.rf.a7071d33d73b4fa00f17bbf34dc037ef.jpg to datasets/classification/val/left\0470.png
# Renamed 0476.png from datasets/classification/val/left\0476_png.rf.8c1a2b426f542443c3e22f2fd54f4be1.jpg to datasets/classification/val/left\0476.png
# Renamed 0479.png from datasets/classification/val/left\0479_png.rf.a91bfd6ad7a0325de6d0059bb31a9a31.jpg to datasets/classification/val/left\0479.png
# Renamed 0485.png from datasets/classification/val/left\0485_png.rf.8a725008dcb1f61e70098bb7531acf36.jpg to datasets/classification/val/left\0485.png
# Renamed 0494.png from datasets/classification/val/left\0494_png.rf.c5b729312402f63e652953c507da069a.jpg to datasets/classification/val/left\0494.png
# Renamed 0496.png from datasets/classification/val/left\0496_png.rf.f84c372625ef36e502e7c71342e1303f.jpg to datasets/classification/val/left\0496.png
# Renamed 0500.png from datasets/classification/val/left\0500_png.rf.17c98f16ef9a081e340d4ee88f865c26.jpg to datasets/classification/val/left\0500.png
# Renamed 0509.png from datasets/classification/val/left\0509_png.rf.c2eb56fce1492292dbb86b31a85555cb.jpg to datasets/classification/val/left\0509.png
# Renamed 0517.png from datasets/classification/val/left\0517_png.rf.b638ae7ce104521e978f8685f23e8934.jpg to datasets/classification/val/left\0517.png
# Renamed 0534.png from datasets/classification/val/left\0534_png.rf.6eb130011939006a4e7410cf6e7f0a0e.jpg to datasets/classification/val/left\0534.png
# Renamed 0538.png from datasets/classification/val/left\0538_png.rf.067410c1ec51434a8ee7bcb064678388.jpg to datasets/classification/val/left\0538.png
# Renamed 0545.png from datasets/classification/val/left\0545_png.rf.2f96e817d1394ca5b2e79a85bc628e66.jpg to datasets/classification/val/left\0545.png
# Renamed 0552.png from datasets/classification/val/left\0552_png.rf.0c3291d25c26997cc95842d651144f46.jpg to datasets/classification/val/left\0552.png
# Renamed 0559.png from datasets/classification/val/left\0559_png.rf.8434fce3b24299d82587926803d51e23.jpg to datasets/classification/val/left\0559.png
# Renamed 0570.png from datasets/classification/val/left\0570_png.rf.d1c4b46ac6b11beda6eb2494a86d7b2a.jpg to datasets/classification/val/left\0570.png
# Renamed 0572.png from datasets/classification/val/left\0572_png.rf.a711562ce90159b8b659670ca1fce393.jpg to datasets/classification/val/left\0572.png
# Renamed 0601.png from datasets/classification/val/left\0601_png.rf.b930078ec82f1fca2ef9d828298f0e71.jpg to datasets/classification/val/left\0601.png
# Renamed 0604.png from datasets/classification/val/left\0604_png.rf.59b5a0a9f2bbb5c0f1dfd73404b2d753.jpg to datasets/classification/val/left\0604.png
# Renamed 0614.png from datasets/classification/val/left\0614_png.rf.8fa580b9b9fcc608f63782603314606f.jpg to datasets/classification/val/left\0614.png
# Renamed 0619.png from datasets/classification/val/left\0619_png.rf.bdcc5930b627cb1fe9b2943ba19a0d87.jpg to datasets/classification/val/left\0619.png
# Renamed 0638.png from datasets/classification/val/left\0638_png.rf.22e5a7e47255e4b2d1eb3ece2c886e59.jpg to datasets/classification/val/left\0638.png
# Renamed 0644.png from datasets/classification/val/left\0644_png.rf.bcb8faae78c8d7d79630d38d49e3c726.jpg to datasets/classification/val/left\0644.png
# Renamed 0658.png from datasets/classification/val/left\0658_png.rf.ea6b6d9b11aaf078a026f1cb036b0b0e.jpg to datasets/classification/val/left\0658.png
# Renamed 0668.png from datasets/classification/val/left\0668_png.rf.933944847369aefb76daf545556ef64d.jpg to datasets/classification/val/left\0668.png
# Renamed 0704.png from datasets/classification/val/left\0704_png.rf.c9286df2c108e62d59b0799a9b548e8e.jpg to datasets/classification/val/left\0704.png
# Renamed 0747.png from datasets/classification/val/left\0747_png.rf.f0db4a1eb8c44c4430ec8cd593b64e37.jpg to datasets/classification/val/left\0747.png
# Renamed 0763.png from datasets/classification/val/left\0763_png.rf.df1a81f3f137a28bcb8faf1a3dd6f997.jpg to datasets/classification/val/left\0763.png
# Renamed 0772.png from datasets/classification/val/left\0772_png.rf.9ff7682308b90ca3e15d798bf95a0f2b.jpg to datasets/classification/val/left\0772.png
# Renamed 0778.png from datasets/classification/val/left\0778_png.rf.5bc8a98233a4b4f5889e4ec6fa60838a.jpg to datasets/classification/val/left\0778.png
# Renamed 0783.png from datasets/classification/val/left\0783_png.rf.6e588eabec383bffa4f82d2e59b2842f.jpg to datasets/classification/val/left\0783.png
# Renamed 0792.png from datasets/classification/val/left\0792_png.rf.9dfb0b6ff9d087fb5f7a1846aaa21ff4.jpg to datasets/classification/val/left\0792.png
# Renamed 0794.png from datasets/classification/val/left\0794_png.rf.b32045f2157bb6bb3554662bd7ec3c40.jpg to datasets/classification/val/left\0794.png

# %%
folder = "datasets/segmentation/optic_disk/train/labels"

for filename in os.listdir(folder):
    if "_mask" in filename:
        new_name = filename.replace("_mask", "")
        old_path = os.path.join(folder, filename)
        new_path = os.path.join(folder, new_name)
        os.rename(old_path, new_path)
        print(f"Renamed: {filename} → {new_name}")
# Out:
# Renamed: 0162_mask.txt → 0162.txt
# Renamed: 0163_mask.txt → 0163.txt
# Renamed: 0164_mask.txt → 0164.txt
# Renamed: 0165_mask.txt → 0165.txt
# Renamed: 0166_mask.txt → 0166.txt
# Renamed: 0167_mask.txt → 0167.txt
# Renamed: 0168_mask.txt → 0168.txt
# Renamed: 0169_mask.txt → 0169.txt
# Renamed: 0170_mask.txt → 0170.txt
# Renamed: 0171_mask.txt → 0171.txt
# Renamed: 0172_mask.txt → 0172.txt
# Renamed: 0173_mask.txt → 0173.txt
# Renamed: 0174_mask.txt → 0174.txt
# Renamed: 0175_mask.txt → 0175.txt
# Renamed: 0176_mask.txt → 0176.txt
# Renamed: 0177_mask.txt → 0177.txt
# Renamed: 0178_mask.txt → 0178.txt
# Renamed: 0179_mask.txt → 0179.txt
# Renamed: 0180_mask.txt → 0180.txt
# Renamed: 0181_mask.txt → 0181.txt
# Renamed: 0182_mask.txt → 0182.txt
# Renamed: 0183_mask.txt → 0183.txt
# Renamed: 0184_mask.txt → 0184.txt
# Renamed: 0185_mask.txt → 0185.txt
# Renamed: 0186_mask.txt → 0186.txt
# Renamed: 0187_mask.txt → 0187.txt
# Renamed: 0188_mask.txt → 0188.txt
# Renamed: 0189_mask.txt → 0189.txt
# Renamed: 0190_mask.txt → 0190.txt
# Renamed: 0191_mask.txt → 0191.txt
# Renamed: 0192_mask.txt → 0192.txt
# Renamed: 0193_mask.txt → 0193.txt
# Renamed: 0194_mask.txt → 0194.txt
# Renamed: 0195_mask.txt → 0195.txt
# Renamed: 0196_mask.txt → 0196.txt
# Renamed: 0197_mask.txt → 0197.txt
# Renamed: 0198_mask.txt → 0198.txt
# Renamed: 0199_mask.txt → 0199.txt
# Renamed: 0200_mask.txt → 0200.txt
# Renamed: 0201_mask.txt → 0201.txt
# Renamed: 0202_mask.txt → 0202.txt
# Renamed: 0203_mask.txt → 0203.txt
# Renamed: 0204_mask.txt → 0204.txt
# Renamed: 0205_mask.txt → 0205.txt
# Renamed: 0206_mask.txt → 0206.txt
# Renamed: 0207_mask.txt → 0207.txt
# Renamed: 0208_mask.txt → 0208.txt
# Renamed: 0209_mask.txt → 0209.txt
# Renamed: 0210_mask.txt → 0210.txt
# Renamed: 0211_mask.txt → 0211.txt
# Renamed: 0212_mask.txt → 0212.txt
# Renamed: 0213_mask.txt → 0213.txt
# Renamed: 0214_mask.txt → 0214.txt
# Renamed: 0215_mask.txt → 0215.txt
# Renamed: 0216_mask.txt → 0216.txt
# Renamed: 0217_mask.txt → 0217.txt
# Renamed: 0218_mask.txt → 0218.txt
# Renamed: 0219_mask.txt → 0219.txt
# Renamed: 0220_mask.txt → 0220.txt
# Renamed: 0221_mask.txt → 0221.txt
# Renamed: 0222_mask.txt → 0222.txt
# Renamed: 0223_mask.txt → 0223.txt
# Renamed: 0224_mask.txt → 0224.txt
# Renamed: 0225_mask.txt → 0225.txt
# Renamed: 0226_mask.txt → 0226.txt
# Renamed: 0227_mask.txt → 0227.txt
# Renamed: 0228_mask.txt → 0228.txt
# Renamed: 0229_mask.txt → 0229.txt
# Renamed: 0230_mask.txt → 0230.txt
# Renamed: 0231_mask.txt → 0231.txt
# Renamed: 0232_mask.txt → 0232.txt
# Renamed: 0233_mask.txt → 0233.txt
# Renamed: 0234_mask.txt → 0234.txt
# Renamed: 0235_mask.txt → 0235.txt
# Renamed: 0236_mask.txt → 0236.txt
# Renamed: 0237_mask.txt → 0237.txt
# Renamed: 0238_mask.txt → 0238.txt
# Renamed: 0239_mask.txt → 0239.txt
# Renamed: 0240_mask.txt → 0240.txt
# Renamed: 0241_mask.txt → 0241.txt
# Renamed: 0242_mask.txt → 0242.txt
# Renamed: 0243_mask.txt → 0243.txt
# Renamed: 0244_mask.txt → 0244.txt
# Renamed: 0245_mask.txt → 0245.txt
# Renamed: 0246_mask.txt → 0246.txt
# Renamed: 0247_mask.txt → 0247.txt
# Renamed: 0248_mask.txt → 0248.txt
# Renamed: 0249_mask.txt → 0249.txt
# Renamed: 0250_mask.txt → 0250.txt
# Renamed: 0251_mask.txt → 0251.txt
# Renamed: 0252_mask.txt → 0252.txt
# Renamed: 0253_mask.txt → 0253.txt
# Renamed: 0254_mask.txt → 0254.txt
# Renamed: 0255_mask.txt → 0255.txt
# Renamed: 0256_mask.txt → 0256.txt
# Renamed: 0257_mask.txt → 0257.txt
# Renamed: 0258_mask.txt → 0258.txt
# Renamed: 0259_mask.txt → 0259.txt
# Renamed: 0260_mask.txt → 0260.txt
# Renamed: 0261_mask.txt → 0261.txt
# Renamed: 0262_mask.txt → 0262.txt
# Renamed: 0263_mask.txt → 0263.txt
# Renamed: 0264_mask.txt → 0264.txt
# Renamed: 0265_mask.txt → 0265.txt
# Renamed: 0266_mask.txt → 0266.txt
# Renamed: 0267_mask.txt → 0267.txt
# Renamed: 0268_mask.txt → 0268.txt
# Renamed: 0269_mask.txt → 0269.txt
# Renamed: 0270_mask.txt → 0270.txt
# Renamed: 0271_mask.txt → 0271.txt
# Renamed: 0272_mask.txt → 0272.txt
# Renamed: 0273_mask.txt → 0273.txt
# Renamed: 0274_mask.txt → 0274.txt
# Renamed: 0275_mask.txt → 0275.txt
# Renamed: 0276_mask.txt → 0276.txt
# Renamed: 0277_mask.txt → 0277.txt
# Renamed: 0278_mask.txt → 0278.txt
# Renamed: 0279_mask.txt → 0279.txt
# Renamed: 0280_mask.txt → 0280.txt
# Renamed: 0281_mask.txt → 0281.txt
# Renamed: 0282_mask.txt → 0282.txt
# Renamed: 0283_mask.txt → 0283.txt
# Renamed: 0284_mask.txt → 0284.txt
# Renamed: 0285_mask.txt → 0285.txt
# Renamed: 0286_mask.txt → 0286.txt
# Renamed: 0287_mask.txt → 0287.txt
# Renamed: 0288_mask.txt → 0288.txt
# Renamed: 0289_mask.txt → 0289.txt
# Renamed: 0290_mask.txt → 0290.txt
# Renamed: 0291_mask.txt → 0291.txt
# Renamed: 0292_mask.txt → 0292.txt
# Renamed: 0293_mask.txt → 0293.txt
# Renamed: 0294_mask.txt → 0294.txt
# Renamed: 0295_mask.txt → 0295.txt
# Renamed: 0296_mask.txt → 0296.txt
# Renamed: 0297_mask.txt → 0297.txt
# Renamed: 0298_mask.txt → 0298.txt
# Renamed: 0299_mask.txt → 0299.txt
# Renamed: 0300_mask.txt → 0300.txt
# Renamed: 0301_mask.txt → 0301.txt
# Renamed: 0302_mask.txt → 0302.txt
# Renamed: 0303_mask.txt → 0303.txt
# Renamed: 0304_mask.txt → 0304.txt
# Renamed: 0305_mask.txt → 0305.txt
# Renamed: 0306_mask.txt → 0306.txt
# Renamed: 0307_mask.txt → 0307.txt
# Renamed: 0308_mask.txt → 0308.txt
# Renamed: 0309_mask.txt → 0309.txt
# Renamed: 0310_mask.txt → 0310.txt
# Renamed: 0311_mask.txt → 0311.txt
# Renamed: 0312_mask.txt → 0312.txt
# Renamed: 0313_mask.txt → 0313.txt
# Renamed: 0314_mask.txt → 0314.txt
# Renamed: 0315_mask.txt → 0315.txt
# Renamed: 0316_mask.txt → 0316.txt
# Renamed: 0317_mask.txt → 0317.txt
# Renamed: 0318_mask.txt → 0318.txt
# Renamed: 0319_mask.txt → 0319.txt
# Renamed: 0320_mask.txt → 0320.txt
# Renamed: 0321_mask.txt → 0321.txt
# Renamed: 0322_mask.txt → 0322.txt
# Renamed: 0323_mask.txt → 0323.txt
# Renamed: 0324_mask.txt → 0324.txt
# Renamed: 0325_mask.txt → 0325.txt
# Renamed: 0326_mask.txt → 0326.txt
# Renamed: 0327_mask.txt → 0327.txt
# Renamed: 0328_mask.txt → 0328.txt
# Renamed: 0329_mask.txt → 0329.txt
# Renamed: 0330_mask.txt → 0330.txt
# Renamed: 0331_mask.txt → 0331.txt
# Renamed: 0332_mask.txt → 0332.txt
# Renamed: 0333_mask.txt → 0333.txt
# Renamed: 0334_mask.txt → 0334.txt
# Renamed: 0335_mask.txt → 0335.txt
# Renamed: 0336_mask.txt → 0336.txt
# Renamed: 0337_mask.txt → 0337.txt
# Renamed: 0338_mask.txt → 0338.txt
# Renamed: 0339_mask.txt → 0339.txt
# Renamed: 0340_mask.txt → 0340.txt
# Renamed: 0341_mask.txt → 0341.txt
# Renamed: 0342_mask.txt → 0342.txt
# Renamed: 0343_mask.txt → 0343.txt
# Renamed: 0344_mask.txt → 0344.txt
# Renamed: 0345_mask.txt → 0345.txt
# Renamed: 0346_mask.txt → 0346.txt
# Renamed: 0347_mask.txt → 0347.txt
# Renamed: 0348_mask.txt → 0348.txt
# Renamed: 0349_mask.txt → 0349.txt
# Renamed: 0350_mask.txt → 0350.txt
# Renamed: 0351_mask.txt → 0351.txt
# Renamed: 0352_mask.txt → 0352.txt
# Renamed: 0353_mask.txt → 0353.txt
# Renamed: 0354_mask.txt → 0354.txt
# Renamed: 0355_mask.txt → 0355.txt
# Renamed: 0356_mask.txt → 0356.txt
# Renamed: 0357_mask.txt → 0357.txt
# Renamed: 0358_mask.txt → 0358.txt
# Renamed: 0359_mask.txt → 0359.txt
# Renamed: 0360_mask.txt → 0360.txt
# Renamed: 0361_mask.txt → 0361.txt
# Renamed: 0362_mask.txt → 0362.txt
# Renamed: 0363_mask.txt → 0363.txt
# Renamed: 0364_mask.txt → 0364.txt
# Renamed: 0365_mask.txt → 0365.txt
# Renamed: 0366_mask.txt → 0366.txt
# Renamed: 0367_mask.txt → 0367.txt
# Renamed: 0368_mask.txt → 0368.txt
# Renamed: 0369_mask.txt → 0369.txt
# Renamed: 0370_mask.txt → 0370.txt
# Renamed: 0371_mask.txt → 0371.txt
# Renamed: 0372_mask.txt → 0372.txt
# Renamed: 0373_mask.txt → 0373.txt
# Renamed: 0374_mask.txt → 0374.txt
# Renamed: 0375_mask.txt → 0375.txt
# Renamed: 0376_mask.txt → 0376.txt
# Renamed: 0377_mask.txt → 0377.txt
# Renamed: 0378_mask.txt → 0378.txt
# Renamed: 0379_mask.txt → 0379.txt
# Renamed: 0380_mask.txt → 0380.txt
# Renamed: 0381_mask.txt → 0381.txt
# Renamed: 0382_mask.txt → 0382.txt
# Renamed: 0383_mask.txt → 0383.txt
# Renamed: 0384_mask.txt → 0384.txt
# Renamed: 0385_mask.txt → 0385.txt
# Renamed: 0386_mask.txt → 0386.txt
# Renamed: 0387_mask.txt → 0387.txt
# Renamed: 0388_mask.txt → 0388.txt
# Renamed: 0389_mask.txt → 0389.txt
# Renamed: 0390_mask.txt → 0390.txt
# Renamed: 0391_mask.txt → 0391.txt
# Renamed: 0392_mask.txt → 0392.txt
# Renamed: 0393_mask.txt → 0393.txt
# Renamed: 0394_mask.txt → 0394.txt
# Renamed: 0395_mask.txt → 0395.txt
# Renamed: 0396_mask.txt → 0396.txt
# Renamed: 0397_mask.txt → 0397.txt
# Renamed: 0398_mask.txt → 0398.txt
# Renamed: 0399_mask.txt → 0399.txt
# Renamed: 0400_mask.txt → 0400.txt
# Renamed: 0401_mask.txt → 0401.txt
# Renamed: 0402_mask.txt → 0402.txt
# Renamed: 0403_mask.txt → 0403.txt
# Renamed: 0404_mask.txt → 0404.txt
# Renamed: 0405_mask.txt → 0405.txt
# Renamed: 0406_mask.txt → 0406.txt
# Renamed: 0407_mask.txt → 0407.txt
# Renamed: 0408_mask.txt → 0408.txt
# Renamed: 0409_mask.txt → 0409.txt
# Renamed: 0410_mask.txt → 0410.txt
# Renamed: 0411_mask.txt → 0411.txt
# Renamed: 0412_mask.txt → 0412.txt
# Renamed: 0413_mask.txt → 0413.txt
# Renamed: 0414_mask.txt → 0414.txt
# Renamed: 0415_mask.txt → 0415.txt
# Renamed: 0416_mask.txt → 0416.txt
# Renamed: 0417_mask.txt → 0417.txt
# Renamed: 0418_mask.txt → 0418.txt
# Renamed: 0419_mask.txt → 0419.txt
# Renamed: 0420_mask.txt → 0420.txt
# Renamed: 0421_mask.txt → 0421.txt
# Renamed: 0422_mask.txt → 0422.txt
# Renamed: 0423_mask.txt → 0423.txt
# Renamed: 0424_mask.txt → 0424.txt
# Renamed: 0425_mask.txt → 0425.txt
# Renamed: 0426_mask.txt → 0426.txt
# Renamed: 0427_mask.txt → 0427.txt
# Renamed: 0428_mask.txt → 0428.txt
# Renamed: 0429_mask.txt → 0429.txt
# Renamed: 0430_mask.txt → 0430.txt
# Renamed: 0431_mask.txt → 0431.txt
# Renamed: 0432_mask.txt → 0432.txt
# Renamed: 0433_mask.txt → 0433.txt
# Renamed: 0434_mask.txt → 0434.txt
# Renamed: 0435_mask.txt → 0435.txt
# Renamed: 0436_mask.txt → 0436.txt
# Renamed: 0437_mask.txt → 0437.txt
# Renamed: 0438_mask.txt → 0438.txt
# Renamed: 0439_mask.txt → 0439.txt
# Renamed: 0440_mask.txt → 0440.txt
# Renamed: 0441_mask.txt → 0441.txt
# Renamed: 0442_mask.txt → 0442.txt
# Renamed: 0443_mask.txt → 0443.txt
# Renamed: 0444_mask.txt → 0444.txt
# Renamed: 0445_mask.txt → 0445.txt
# Renamed: 0446_mask.txt → 0446.txt
# Renamed: 0447_mask.txt → 0447.txt
# Renamed: 0448_mask.txt → 0448.txt
# Renamed: 0449_mask.txt → 0449.txt
# Renamed: 0450_mask.txt → 0450.txt
# Renamed: 0451_mask.txt → 0451.txt
# Renamed: 0452_mask.txt → 0452.txt
# Renamed: 0453_mask.txt → 0453.txt
# Renamed: 0454_mask.txt → 0454.txt
# Renamed: 0455_mask.txt → 0455.txt
# Renamed: 0456_mask.txt → 0456.txt
# Renamed: 0457_mask.txt → 0457.txt
# Renamed: 0458_mask.txt → 0458.txt
# Renamed: 0459_mask.txt → 0459.txt
# Renamed: 0460_mask.txt → 0460.txt
# Renamed: 0461_mask.txt → 0461.txt
# Renamed: 0462_mask.txt → 0462.txt
# Renamed: 0463_mask.txt → 0463.txt
# Renamed: 0464_mask.txt → 0464.txt
# Renamed: 0465_mask.txt → 0465.txt
# Renamed: 0466_mask.txt → 0466.txt
# Renamed: 0467_mask.txt → 0467.txt
# Renamed: 0468_mask.txt → 0468.txt
# Renamed: 0469_mask.txt → 0469.txt
# Renamed: 0470_mask.txt → 0470.txt
# Renamed: 0471_mask.txt → 0471.txt
# Renamed: 0472_mask.txt → 0472.txt
# Renamed: 0473_mask.txt → 0473.txt
# Renamed: 0474_mask.txt → 0474.txt
# Renamed: 0475_mask.txt → 0475.txt
# Renamed: 0476_mask.txt → 0476.txt
# Renamed: 0477_mask.txt → 0477.txt
# Renamed: 0478_mask.txt → 0478.txt
# Renamed: 0479_mask.txt → 0479.txt
# Renamed: 0480_mask.txt → 0480.txt
# Renamed: 0481_mask.txt → 0481.txt
# Renamed: 0482_mask.txt → 0482.txt
# Renamed: 0483_mask.txt → 0483.txt
# Renamed: 0484_mask.txt → 0484.txt
# Renamed: 0485_mask.txt → 0485.txt
# Renamed: 0486_mask.txt → 0486.txt
# Renamed: 0487_mask.txt → 0487.txt
# Renamed: 0488_mask.txt → 0488.txt
# Renamed: 0489_mask.txt → 0489.txt
# Renamed: 0490_mask.txt → 0490.txt
# Renamed: 0491_mask.txt → 0491.txt
# Renamed: 0492_mask.txt → 0492.txt
# Renamed: 0493_mask.txt → 0493.txt
# Renamed: 0494_mask.txt → 0494.txt
# Renamed: 0495_mask.txt → 0495.txt
# Renamed: 0496_mask.txt → 0496.txt
# Renamed: 0497_mask.txt → 0497.txt
# Renamed: 0498_mask.txt → 0498.txt
# Renamed: 0499_mask.txt → 0499.txt
# Renamed: 0500_mask.txt → 0500.txt
# Renamed: 0501_mask.txt → 0501.txt
# Renamed: 0502_mask.txt → 0502.txt
# Renamed: 0503_mask.txt → 0503.txt
# Renamed: 0504_mask.txt → 0504.txt
# Renamed: 0505_mask.txt → 0505.txt
# Renamed: 0506_mask.txt → 0506.txt
# Renamed: 0507_mask.txt → 0507.txt
# Renamed: 0508_mask.txt → 0508.txt
# Renamed: 0509_mask.txt → 0509.txt
# Renamed: 0510_mask.txt → 0510.txt
# Renamed: 0511_mask.txt → 0511.txt
# Renamed: 0512_mask.txt → 0512.txt
# Renamed: 0513_mask.txt → 0513.txt
# Renamed: 0514_mask.txt → 0514.txt
# Renamed: 0515_mask.txt → 0515.txt
# Renamed: 0516_mask.txt → 0516.txt
# Renamed: 0517_mask.txt → 0517.txt
# Renamed: 0518_mask.txt → 0518.txt
# Renamed: 0519_mask.txt → 0519.txt
# Renamed: 0520_mask.txt → 0520.txt
# Renamed: 0521_mask.txt → 0521.txt
# Renamed: 0522_mask.txt → 0522.txt
# Renamed: 0523_mask.txt → 0523.txt
# Renamed: 0524_mask.txt → 0524.txt
# Renamed: 0525_mask.txt → 0525.txt
# Renamed: 0526_mask.txt → 0526.txt
# Renamed: 0527_mask.txt → 0527.txt
# Renamed: 0528_mask.txt → 0528.txt
# Renamed: 0529_mask.txt → 0529.txt
# Renamed: 0530_mask.txt → 0530.txt
# Renamed: 0531_mask.txt → 0531.txt
# Renamed: 0532_mask.txt → 0532.txt
# Renamed: 0533_mask.txt → 0533.txt
# Renamed: 0534_mask.txt → 0534.txt
# Renamed: 0535_mask.txt → 0535.txt
# Renamed: 0536_mask.txt → 0536.txt
# Renamed: 0537_mask.txt → 0537.txt
# Renamed: 0538_mask.txt → 0538.txt
# Renamed: 0539_mask.txt → 0539.txt
# Renamed: 0540_mask.txt → 0540.txt
# Renamed: 0541_mask.txt → 0541.txt
# Renamed: 0542_mask.txt → 0542.txt
# Renamed: 0543_mask.txt → 0543.txt
# Renamed: 0544_mask.txt → 0544.txt
# Renamed: 0545_mask.txt → 0545.txt
# Renamed: 0546_mask.txt → 0546.txt
# Renamed: 0547_mask.txt → 0547.txt
# Renamed: 0548_mask.txt → 0548.txt
# Renamed: 0549_mask.txt → 0549.txt
# Renamed: 0550_mask.txt → 0550.txt
# Renamed: 0551_mask.txt → 0551.txt
# Renamed: 0552_mask.txt → 0552.txt
# Renamed: 0553_mask.txt → 0553.txt
# Renamed: 0554_mask.txt → 0554.txt
# Renamed: 0555_mask.txt → 0555.txt
# Renamed: 0556_mask.txt → 0556.txt
# Renamed: 0557_mask.txt → 0557.txt
# Renamed: 0558_mask.txt → 0558.txt
# Renamed: 0559_mask.txt → 0559.txt
# Renamed: 0560_mask.txt → 0560.txt
# Renamed: 0561_mask.txt → 0561.txt
# Renamed: 0562_mask.txt → 0562.txt
# Renamed: 0563_mask.txt → 0563.txt
# Renamed: 0564_mask.txt → 0564.txt
# Renamed: 0565_mask.txt → 0565.txt
# Renamed: 0566_mask.txt → 0566.txt
# Renamed: 0567_mask.txt → 0567.txt
# Renamed: 0568_mask.txt → 0568.txt
# Renamed: 0569_mask.txt → 0569.txt
# Renamed: 0570_mask.txt → 0570.txt
# Renamed: 0571_mask.txt → 0571.txt
# Renamed: 0572_mask.txt → 0572.txt
# Renamed: 0573_mask.txt → 0573.txt
# Renamed: 0574_mask.txt → 0574.txt
# Renamed: 0575_mask.txt → 0575.txt
# Renamed: 0576_mask.txt → 0576.txt
# Renamed: 0577_mask.txt → 0577.txt
# Renamed: 0578_mask.txt → 0578.txt
# Renamed: 0579_mask.txt → 0579.txt
# Renamed: 0580_mask.txt → 0580.txt
# Renamed: 0581_mask.txt → 0581.txt
# Renamed: 0582_mask.txt → 0582.txt
# Renamed: 0583_mask.txt → 0583.txt
# Renamed: 0584_mask.txt → 0584.txt
# Renamed: 0585_mask.txt → 0585.txt
# Renamed: 0586_mask.txt → 0586.txt
# Renamed: 0587_mask.txt → 0587.txt
# Renamed: 0588_mask.txt → 0588.txt
# Renamed: 0589_mask.txt → 0589.txt
# Renamed: 0590_mask.txt → 0590.txt
# Renamed: 0591_mask.txt → 0591.txt
# Renamed: 0592_mask.txt → 0592.txt
# Renamed: 0593_mask.txt → 0593.txt
# Renamed: 0594_mask.txt → 0594.txt
# Renamed: 0595_mask.txt → 0595.txt
# Renamed: 0596_mask.txt → 0596.txt
# Renamed: 0597_mask.txt → 0597.txt
# Renamed: 0598_mask.txt → 0598.txt
# Renamed: 0599_mask.txt → 0599.txt
# Renamed: 0600_mask.txt → 0600.txt
# Renamed: 0601_mask.txt → 0601.txt
# Renamed: 0602_mask.txt → 0602.txt
# Renamed: 0603_mask.txt → 0603.txt
# Renamed: 0604_mask.txt → 0604.txt
# Renamed: 0605_mask.txt → 0605.txt
# Renamed: 0606_mask.txt → 0606.txt
# Renamed: 0607_mask.txt → 0607.txt
# Renamed: 0608_mask.txt → 0608.txt
# Renamed: 0609_mask.txt → 0609.txt
# Renamed: 0610_mask.txt → 0610.txt
# Renamed: 0611_mask.txt → 0611.txt
# Renamed: 0612_mask.txt → 0612.txt
# Renamed: 0613_mask.txt → 0613.txt
# Renamed: 0614_mask.txt → 0614.txt
# Renamed: 0615_mask.txt → 0615.txt
# Renamed: 0616_mask.txt → 0616.txt
# Renamed: 0617_mask.txt → 0617.txt
# Renamed: 0618_mask.txt → 0618.txt
# Renamed: 0619_mask.txt → 0619.txt
# Renamed: 0620_mask.txt → 0620.txt
# Renamed: 0621_mask.txt → 0621.txt
# Renamed: 0622_mask.txt → 0622.txt
# Renamed: 0623_mask.txt → 0623.txt
# Renamed: 0624_mask.txt → 0624.txt
# Renamed: 0625_mask.txt → 0625.txt
# Renamed: 0626_mask.txt → 0626.txt
# Renamed: 0627_mask.txt → 0627.txt
# Renamed: 0628_mask.txt → 0628.txt
# Renamed: 0629_mask.txt → 0629.txt
# Renamed: 0630_mask.txt → 0630.txt
# Renamed: 0631_mask.txt → 0631.txt
# Renamed: 0632_mask.txt → 0632.txt
# Renamed: 0633_mask.txt → 0633.txt
# Renamed: 0634_mask.txt → 0634.txt
# Renamed: 0635_mask.txt → 0635.txt
# Renamed: 0636_mask.txt → 0636.txt
# Renamed: 0637_mask.txt → 0637.txt
# Renamed: 0638_mask.txt → 0638.txt
# Renamed: 0639_mask.txt → 0639.txt
# Renamed: 0640_mask.txt → 0640.txt
# Renamed: 0641_mask.txt → 0641.txt
# Renamed: 0642_mask.txt → 0642.txt
# Renamed: 0643_mask.txt → 0643.txt
# Renamed: 0644_mask.txt → 0644.txt
# Renamed: 0645_mask.txt → 0645.txt
# Renamed: 0646_mask.txt → 0646.txt
# Renamed: 0647_mask.txt → 0647.txt
# Renamed: 0648_mask.txt → 0648.txt
# Renamed: 0649_mask.txt → 0649.txt
# Renamed: 0650_mask.txt → 0650.txt
# Renamed: 0651_mask.txt → 0651.txt
# Renamed: 0652_mask.txt → 0652.txt
# Renamed: 0653_mask.txt → 0653.txt
# Renamed: 0654_mask.txt → 0654.txt
# Renamed: 0655_mask.txt → 0655.txt
# Renamed: 0656_mask.txt → 0656.txt
# Renamed: 0657_mask.txt → 0657.txt
# Renamed: 0658_mask.txt → 0658.txt
# Renamed: 0659_mask.txt → 0659.txt
# Renamed: 0660_mask.txt → 0660.txt
# Renamed: 0661_mask.txt → 0661.txt
# Renamed: 0662_mask.txt → 0662.txt
# Renamed: 0663_mask.txt → 0663.txt
# Renamed: 0664_mask.txt → 0664.txt
# Renamed: 0665_mask.txt → 0665.txt
# Renamed: 0666_mask.txt → 0666.txt
# Renamed: 0667_mask.txt → 0667.txt
# Renamed: 0668_mask.txt → 0668.txt
# Renamed: 0669_mask.txt → 0669.txt
# Renamed: 0670_mask.txt → 0670.txt
# Renamed: 0671_mask.txt → 0671.txt
# Renamed: 0672_mask.txt → 0672.txt
# Renamed: 0673_mask.txt → 0673.txt
# Renamed: 0674_mask.txt → 0674.txt
# Renamed: 0675_mask.txt → 0675.txt
# Renamed: 0676_mask.txt → 0676.txt
# Renamed: 0677_mask.txt → 0677.txt
# Renamed: 0678_mask.txt → 0678.txt
# Renamed: 0679_mask.txt → 0679.txt
# Renamed: 0680_mask.txt → 0680.txt
# Renamed: 0681_mask.txt → 0681.txt
# Renamed: 0682_mask.txt → 0682.txt
# Renamed: 0683_mask.txt → 0683.txt
# Renamed: 0684_mask.txt → 0684.txt
# Renamed: 0685_mask.txt → 0685.txt
# Renamed: 0686_mask.txt → 0686.txt
# Renamed: 0687_mask.txt → 0687.txt
# Renamed: 0688_mask.txt → 0688.txt
# Renamed: 0689_mask.txt → 0689.txt
# Renamed: 0690_mask.txt → 0690.txt
# Renamed: 0691_mask.txt → 0691.txt
# Renamed: 0692_mask.txt → 0692.txt
# Renamed: 0693_mask.txt → 0693.txt
# Renamed: 0694_mask.txt → 0694.txt
# Renamed: 0695_mask.txt → 0695.txt
# Renamed: 0696_mask.txt → 0696.txt
# Renamed: 0697_mask.txt → 0697.txt
# Renamed: 0698_mask.txt → 0698.txt
# Renamed: 0699_mask.txt → 0699.txt
# Renamed: 0700_mask.txt → 0700.txt
# Renamed: 0701_mask.txt → 0701.txt
# Renamed: 0702_mask.txt → 0702.txt
# Renamed: 0703_mask.txt → 0703.txt
# Renamed: 0704_mask.txt → 0704.txt
# Renamed: 0705_mask.txt → 0705.txt
# Renamed: 0706_mask.txt → 0706.txt
# Renamed: 0707_mask.txt → 0707.txt
# Renamed: 0708_mask.txt → 0708.txt
# Renamed: 0709_mask.txt → 0709.txt
# Renamed: 0710_mask.txt → 0710.txt
# Renamed: 0711_mask.txt → 0711.txt
# Renamed: 0712_mask.txt → 0712.txt
# Renamed: 0713_mask.txt → 0713.txt
# Renamed: 0714_mask.txt → 0714.txt
# Renamed: 0715_mask.txt → 0715.txt
# Renamed: 0716_mask.txt → 0716.txt
# Renamed: 0717_mask.txt → 0717.txt
# Renamed: 0718_mask.txt → 0718.txt
# Renamed: 0719_mask.txt → 0719.txt
# Renamed: 0720_mask.txt → 0720.txt
# Renamed: 0721_mask.txt → 0721.txt
# Renamed: 0722_mask.txt → 0722.txt
# Renamed: 0723_mask.txt → 0723.txt
# Renamed: 0724_mask.txt → 0724.txt
# Renamed: 0725_mask.txt → 0725.txt
# Renamed: 0726_mask.txt → 0726.txt
# Renamed: 0727_mask.txt → 0727.txt
# Renamed: 0728_mask.txt → 0728.txt
# Renamed: 0729_mask.txt → 0729.txt
# Renamed: 0730_mask.txt → 0730.txt
# Renamed: 0731_mask.txt → 0731.txt
# Renamed: 0732_mask.txt → 0732.txt
# Renamed: 0733_mask.txt → 0733.txt
# Renamed: 0734_mask.txt → 0734.txt
# Renamed: 0735_mask.txt → 0735.txt
# Renamed: 0736_mask.txt → 0736.txt
# Renamed: 0737_mask.txt → 0737.txt
# Renamed: 0738_mask.txt → 0738.txt
# Renamed: 0739_mask.txt → 0739.txt
# Renamed: 0740_mask.txt → 0740.txt
# Renamed: 0741_mask.txt → 0741.txt
# Renamed: 0742_mask.txt → 0742.txt
# Renamed: 0743_mask.txt → 0743.txt
# Renamed: 0744_mask.txt → 0744.txt
# Renamed: 0745_mask.txt → 0745.txt
# Renamed: 0746_mask.txt → 0746.txt
# Renamed: 0747_mask.txt → 0747.txt
# Renamed: 0748_mask.txt → 0748.txt
# Renamed: 0749_mask.txt → 0749.txt
# Renamed: 0750_mask.txt → 0750.txt
# Renamed: 0751_mask.txt → 0751.txt
# Renamed: 0752_mask.txt → 0752.txt
# Renamed: 0753_mask.txt → 0753.txt
# Renamed: 0754_mask.txt → 0754.txt
# Renamed: 0755_mask.txt → 0755.txt
# Renamed: 0756_mask.txt → 0756.txt
# Renamed: 0757_mask.txt → 0757.txt
# Renamed: 0758_mask.txt → 0758.txt
# Renamed: 0759_mask.txt → 0759.txt
# Renamed: 0760_mask.txt → 0760.txt
# Renamed: 0761_mask.txt → 0761.txt
# Renamed: 0762_mask.txt → 0762.txt
# Renamed: 0763_mask.txt → 0763.txt
# Renamed: 0764_mask.txt → 0764.txt
# Renamed: 0765_mask.txt → 0765.txt
# Renamed: 0766_mask.txt → 0766.txt
# Renamed: 0767_mask.txt → 0767.txt
# Renamed: 0768_mask.txt → 0768.txt
# Renamed: 0769_mask.txt → 0769.txt
# Renamed: 0770_mask.txt → 0770.txt
# Renamed: 0771_mask.txt → 0771.txt
# Renamed: 0772_mask.txt → 0772.txt
# Renamed: 0773_mask.txt → 0773.txt
# Renamed: 0774_mask.txt → 0774.txt
# Renamed: 0775_mask.txt → 0775.txt
# Renamed: 0776_mask.txt → 0776.txt
# Renamed: 0777_mask.txt → 0777.txt
# Renamed: 0778_mask.txt → 0778.txt
# Renamed: 0779_mask.txt → 0779.txt
# Renamed: 0780_mask.txt → 0780.txt
# Renamed: 0781_mask.txt → 0781.txt
# Renamed: 0782_mask.txt → 0782.txt
# Renamed: 0783_mask.txt → 0783.txt
# Renamed: 0784_mask.txt → 0784.txt
# Renamed: 0785_mask.txt → 0785.txt
# Renamed: 0786_mask.txt → 0786.txt
# Renamed: 0787_mask.txt → 0787.txt
# Renamed: 0788_mask.txt → 0788.txt
# Renamed: 0789_mask.txt → 0789.txt
# Renamed: 0790_mask.txt → 0790.txt
# Renamed: 0791_mask.txt → 0791.txt
# Renamed: 0792_mask.txt → 0792.txt
# Renamed: 0793_mask.txt → 0793.txt
# Renamed: 0794_mask.txt → 0794.txt
# Renamed: 0795_mask.txt → 0795.txt
# Renamed: 0796_mask.txt → 0796.txt
# Renamed: 0797_mask.txt → 0797.txt
# Renamed: 0798_mask.txt → 0798.txt
# Renamed: 0799_mask.txt → 0799.txt
# Renamed: 0800_mask.txt → 0800.txt
# Renamed: 0801_mask.txt → 0801.txt
# Renamed: 0802_mask.txt → 0802.txt
# Renamed: 0803_mask.txt → 0803.txt
# Renamed: 0804_mask.txt → 0804.txt
# Renamed: 0805_mask.txt → 0805.txt

# %%
# Path to your mask folder
masks_dir = Path("data/eye/train_masks")

# Get first 30 masks
mask_paths = sorted(masks_dir.glob("*.png"))[200:230]

# Create display grid
plt.figure(figsize=(20, 15))

for i, mask_path in enumerate(mask_paths):
    # Read grayscale mask
    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
    h, w = mask.shape

    # Binarize
    _, mask_bin = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    # Find contours
    contours, _ = cv2.findContours(mask_bin, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"No contour found in {mask_path.name}")
        continue

    contour = max(contours, key=cv2.contourArea)

    # Bounding box
    x, y, bw, bh = cv2.boundingRect(contour)

    # Enclosing circle
    (xc, yc), radius = cv2.minEnclosingCircle(contour)
    center = (int(xc), int(yc))
    radius = int(radius)

    # Prepare visualization
    vis = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

    # Draw contour (green)
    cv2.drawContours(vis, [contour], -1, (0, 255, 0), 1)

    # Draw bounding box (red)
    cv2.rectangle(vis, (x, y), (x + bw, y + bh), (0, 0, 255), 2)

    # Draw enclosing circle (blue)
    cv2.circle(vis, center, radius, (255, 0, 0), 2)
    cv2.circle(vis, center, 2, (255, 0, 0), -1)  # dot at center

    # Display
    plt.subplot(5, 6, i + 1)
    plt.imshow(vis)
    plt.title(mask_path.name, fontsize=8)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Paths
masks_dir = Path("data/eye/train_masks")
labels_dir = Path("data/eye/train_labels")
labels_dir.mkdir(parents=True, exist_ok=True)

# Single class
class_id = 0  # you can change this if needed

for mask_path in masks_dir.glob("*.png"):
    # Read mask in grayscale
    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
    h, w = mask.shape

    # Threshold to ensure binary mask
    _, mask_bin = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    # Find contours
    contours, _ = cv2.findContours(mask_bin, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"No contour found in {mask_path.name}")
        continue

    # Find largest contour (since there’s only one circle)
    contour = max(contours, key=cv2.contourArea)

    # Get bounding box
    x, y, bw, bh = cv2.boundingRect(contour)

    # Convert to YOLO normalized format
    x_center = (x + bw / 2) / w
    y_center = (y + bh / 2) / h
    bw /= w
    bh /= h

    # Write YOLO label file
    label_path = labels_dir / f"{mask_path.stem}.txt"
    with open(label_path, "w") as f:
        f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {bw:.6f} {bh:.6f}\n")

# %%
# Paths
masks_dir = Path("datasets/segmentation/optic_disk/train/images")       # Folder with binary PNGs
labels_dir = Path("datasets/segmentation/optic_disk/train/labels")     # Output folder for YOLO segmentation labels
labels_dir.mkdir(parents=True, exist_ok=True)

# One class only
CLASS_ID = 0

for mask_path in masks_dir.glob("*.png"):
    # Read mask as grayscale
    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
    h, w = mask.shape

    # Threshold to ensure binary
    _, mask_bin = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    # Find contours (external only)
    contours, _ = cv2.findContours(mask_bin, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    label_path = labels_dir / f"{mask_path.stem}.txt"

    with open(label_path, "w") as f:
        for contour in contours:
            # Flatten contour and normalize
            contour = contour.squeeze()
            if len(contour.shape) != 2:  # skip empty contours
                continue

            normalized = []
            for x, y in contour:
                normalized.append(f"{x / w:.6f}")
                normalized.append(f"{y / h:.6f}")

            # Write one line per object
            f.write(f"{CLASS_ID} " + " ".join(normalized) + "\n")

print("✅ Conversion complete! Labels saved in:", labels_dir)
# Out:
# ✅ Conversion complete! Labels saved in: datasets\segmentation\optic_disk\train\labels

# %%
# Paths
images_dir = Path("datasets/segmentation/optic_disk/val/images")   # Folder with your original images
labels_dir = Path("datasets/segmentation/optic_disk/val/labels")   # Folder with YOLO .txt segmentation labels

# Number of samples to show
N = 30

# Get list of image paths
image_paths = sorted(list(images_dir.glob("*.png")))[:N]

def load_yolo_polygons(label_path, w, h):
    polygons = []
    if not label_path.exists():
        return polygons
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 3:
                continue
            coords = np.array(list(map(float, parts[1:])))
            pts = coords.reshape(-1, 2)
            pts[:, 0] *= w
            pts[:, 1] *= h
            polygons.append(pts.astype(np.int32))
    return polygons

cols = 4
rows = int(np.ceil(N / cols))
plt.figure(figsize=(4 * cols, 4 * rows))

for i, image_path in enumerate(image_paths):
    label_path = labels_dir / (image_path.stem + ".txt")
    img = cv2.imread(str(image_path))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w, _ = img.shape

    polygons = load_yolo_polygons(label_path, w, h)

    # Create transparent overlay
    overlay = img.copy()
    for pts in polygons:
        cv2.fillPoly(overlay, [pts], color=(0, 255, 0))  # green fill
        cv2.polylines(overlay, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

    # Blend overlay with original image (alpha = 0.1 means 10% green)
    blended = cv2.addWeighted(overlay, 0.1, img, 0.9, 0)

    plt.subplot(rows, cols, i + 1)
    plt.imshow(blended)
    plt.axis("off")
    plt.title(image_path.stem)

plt.tight_layout()
plt.show()
